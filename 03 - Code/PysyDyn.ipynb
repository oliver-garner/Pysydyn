# %% [markdown]
# ## This is a testing script for the flow and workability
#
# mimicing the main script

# %%
#%% import package
import numpy as np
import __init__
from turbie_and_floaty import TurbieAndFloatyInWindyWavy
from windy_and_wavy import WindyWavy

# no easy way to calculate matrix b, to be done by WAMIT
matrix_b = np.array([[2e5, 0, 0],
                     [0, 0, 0],
                     [0, 0, 0]])

testing_instance = \
    TurbieAndFloatyInWindyWavy(file_windy_wavy='PysyDyn_Windy_Wavy_Default.csv',
                               file_floaty='PysyDn_Floaty_Default.csv',
                               file_turbie='PysyDyn_Turbie_Default.csv', 
                                matrix_b = matrix_b)

# %%
testing_instance.run_program(save_response = True,
                             show_plot = True,
                             you_decide_plot_name = 'default response',
                             show_windywavy_plot = True)
